# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
mkdir -p /content/drive/MyDrive/Object_Detection/License_Plate_Recognition

# %%
# %cd /content/drive/MyDrive/Object_Detection/License_Plate_Recognition
# Out:
# /content/drive/MyDrive/Object_Detection/License_Plate_Recognition

# %%
# Check Dir Root
import os
Home = os.getcwd()
print(Home)
# Out:
# /content/drive/MyDrive/Object_Detection/License_Plate_Recognition

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

# %%
# Check ultralystics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.190 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
# !pip install roboflow
display.clear_output()

# %%
# !mkdir {Home}/DataSets
# %cd {Home}/DataSets
# Out:
# /content/drive/MyDrive/Object_Detection/License_Plate_Recognition/DataSets

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="3xqoQhgk2T2SnBmvFHiE")
project = rf.workspace("roboflow-universe-projects").project("license-plate-recognition-rxg4e")
dataset = project.version(4).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.190, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to License-Plate-Recognition-4 in yolov8:: 100%|██████████| 48488/48488 [07:19<00:00, 110.32it/s]

# %%
# %cd {Home}
from ultralytics import YOLO
# Load a model
model = YOLO('yolov8m.pt')  # load a pretrained model (recommended for training)

data_path= '/content/drive/MyDrive/Object_Detection/License_Plate_Recognition/DataSets/License-Plate-Recognition-4/data.yaml'
# Train the model
result = model.train(data= data_path , epochs=25, imgsz=600,plots=True)
# Out:
# /content/drive/MyDrive/Object_Detection/License_Plate_Recognition
# Ultralytics YOLOv8.0.190 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
